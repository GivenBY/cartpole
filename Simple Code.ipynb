# %%
import gymnasium as gym

env = gym.make("CartPole-v1", render_mode="human")

for i_episode in range(100):
    obs, info = env.reset()   # reset now returns (obs, info)
    t = 0
    done = False
    while not done:
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        t += 1
        if done:
            print(f"Episode {i_episode + 1}: finished after {t} steps")
            break

env.close()
# Out:
# Episode 1: finished after 13 steps
# Episode 2: finished after 12 steps
# Episode 3: finished after 35 steps
# Episode 4: finished after 21 steps
# Episode 5: finished after 18 steps
# Episode 6: finished after 12 steps
# Episode 7: finished after 27 steps
# Episode 8: finished after 12 steps
# Episode 9: finished after 50 steps
# Episode 10: finished after 16 steps
# Episode 11: finished after 21 steps
# Episode 12: finished after 12 steps
# Episode 13: finished after 23 steps
# Episode 14: finished after 19 steps
# Episode 15: finished after 17 steps
# Episode 16: finished after 21 steps
# Episode 17: finished after 10 steps
# Episode 18: finished after 19 steps
# Episode 19: finished after 12 steps
# Episode 20: finished after 15 steps
# Episode 21: finished after 13 steps
# Episode 22: finished after 30 steps
# Episode 23: finished after 16 steps
# Episode 24: finished after 11 steps
# Episode 25: finished after 14 steps
# Episode 26: finished after 14 steps
# Episode 27: finished after 36 steps
# Episode 28: finished after 16 steps
# Episode 29: finished after 13 steps
# Episode 30: finished after 14 steps
# Episode 31: finished after 26 steps
# Episode 32: finished after 36 steps
# Episode 33: finished after 15 steps
# Episode 34: finished after 13 steps
# Episode 35: finished after 23 steps
# Episode 36: finished after 10 steps
# Episode 37: finished after 11 steps
# Episode 38: finished after 23 steps
# Episode 39: finished after 13 steps
# Episode 40: finished after 30 steps
# Episode 41: finished after 24 steps
# Episode 42: finished after 17 steps
# Episode 43: finished after 17 steps
# Episode 44: finished after 37 steps
# Episode 45: finished after 15 steps
# Episode 46: finished after 15 steps
# Episode 47: finished after 14 steps
# Episode 48: finished after 32 steps
# Episode 49: finished after 38 steps
# Episode 50: finished after 14 steps
# Episode 51: finished after 13 steps
# Episode 52: finished after 29 steps
# Episode 53: finished after 18 steps
# Episode 54: finished after 16 steps
# Episode 55: finished after 14 steps
# Episode 56: finished after 15 steps
# Episode 57: finished after 9 steps
# Episode 58: finished after 22 steps
# Episode 59: finished after 15 steps
# Episode 60: finished after 44 steps
# Episode 61: finished after 19 steps
# Episode 62: finished after 18 steps
# Episode 63: finished after 12 steps
# Episode 64: finished after 12 steps
# Episode 65: finished after 28 steps
# Episode 66: finished after 13 steps
# Episode 67: finished after 33 steps
# Episode 68: finished after 11 steps
# Episode 69: finished after 19 steps
# Episode 70: finished after 15 steps
# Episode 71: finished after 90 steps
# Episode 72: finished after 64 steps
# Episode 73: finished after 14 steps
# Episode 74: finished after 15 steps
# Episode 75: finished after 33 steps
# Episode 76: finished after 32 steps
# Episode 77: finished after 47 steps
# Episode 78: finished after 10 steps
# Episode 79: finished after 37 steps
# Episode 80: finished after 29 steps
# Episode 81: finished after 12 steps
# Episode 82: finished after 16 steps
# Episode 83: finished after 19 steps
# Episode 84: finished after 81 steps
# Episode 85: finished after 15 steps
# Episode 86: finished after 17 steps
# Episode 87: finished after 24 steps
# Episode 88: finished after 31 steps
# Episode 89: finished after 19 steps
# Episode 90: finished after 18 steps
# Episode 91: finished after 16 steps
# Episode 92: finished after 12 steps
# Episode 93: finished after 17 steps
# Episode 94: finished after 47 steps
# Episode 95: finished after 36 steps
# Episode 96: finished after 22 steps
# Episode 97: finished after 13 steps
# Episode 98: finished after 14 steps
# Episode 99: finished after 26 steps
# Episode 100: finished after 27 steps
